# %%
import pandas as pd
import json

data = '''

[{"id":"113","af_id":998,"company_id":"113","invoice_start_date":"2021-11-01T00:00:00.000Z","invoice_end_date":"2021-12-01T00:00:00.000Z","datetime_read":null,"dados_fatura":{"grupo":"A","status":"NAOREALIZADA","cliente":"Freitas Varejo","subgrupo":"4","cidade_uf":"Rua Jose Pontes 33","id_fatura":-1,"numero_uc":"9004369","taxa_icms":27,"modalidade":"","updated_at":"2023-08-01T20:02:26.897762+00:00","taxa_cofins":2.78,"data_criacao":"2023-07-06T14:52:35.48096+00:00","data_emissao":"2021-12-20","aws_file_name":"7_113_2021-12_4_6_24_2021-12-01_9004369_-_12.2021.pdf","company_group":7,"ano_referencia":2021,"numero_cliente":"9004369","taxa_pis_pasep":0.62,"datetime_update":"2022-07-25T00:34:22.903584","sistema_horossazonal":"verde","tipo_de_fornecimento":"","numero_mes_referencia":12,"taxa_consumo_ponta_te":0.56151,"contratou_mercado_livre":false,"taxa_consumo_ponta_tusd":1.69777,"valor_distribuidora_cip":392.57,"valor_distribuidora_icms":671.79,"taxa_excedente_ufer_ponta":0.3625,"origem_dos_dados_da_fatura":"","taxa_consumo_fora_ponta_te":0.34683,"valor_distribuidora_cofins":28.75,"taxa_consumo_fora_ponta_tusd":0.08538,"valor_distribuidora_pis_pasep":6.39,"taxa_excedente_ufer_fp_indutivo":0.36463,"taxa_demanda_fora_ponta_indutivo":26.99958,"medicao_distribuidora_consumo_ponta_te":746,"taxa_demanda_fora_ponta_indutivo_s_icms":19.71018,"medicao_distribuidora_consumo_ponta_tusd":746,"medicao_distribuidora_excedente_ufer_ponta":16,"medicao_distribuidora_consumo_fora_ponta_te":5299,"taxa_bandeira_tarifaria_vermelha_fora_ponta":1,"taxa_energia_ativa_injetada_ponta_ouc_mpt_te":-0.56151,"medicao_distribuidora_consumo_fora_ponta_tusd":5299,"taxa_energia_ativa_injetada_ponta_ouc_mpt_tusd":-1.23938,"medicao_distribuidora_energia_ativa_ponta_saldo":431,"medicao_distribuidora_excedente_ufer_fp_indutivo":315,"medicao_distribuidora_demanda_fora_ponta_indutivo":24.02,"medicao_distribuidora_energia_ativa_ponta_credito":746,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_te":-0.34683,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_te":5299,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":-0.06233,"medicao_distribuidora_energia_ativa_fora_ponta_saldo":16611.78,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":5299,"medicao_distribuidora_energia_ativa_fora_ponta_credito":5299,"taxa_bandeira_tarifaria_vermelha_fora_ponta_compensado":1,"m_dist_bandeira_tarifaria_vermelha_fora_ponta_compensado":-1217.21,"medicao_distribuidora_demanda_fora_ponta_indutivo_s_icms":23.98,"medicao_distribuidora_bandeira_tarifaria_vermelha_fora_ponta":1217.23,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_te":746,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_tusd":746},"updated_at":"2024-09-21T07:59:36.870Z","rent_calc":true,"af_sync":true,"company_name":"Freitas Varejo","subsidiary_name":"Rua Jose Pontes 33","subsidiary_type":1,"created_at":"2022-03-30T20:00:00.000Z","deleted_at":null,"latitude":null,"longitude":null,"contact_name":null,"contact_phone":null,"contact_address":null,"address":"","number":"0","complement":"","district":"","city_id":null,"state_id":6,"country_id":null,"zip":"","hour_point_start":"17:30:00","hour_point_end":"20:30:00","hour_hr_start":"21:30:00","hour_hr_end":"06:00:00","company_group":"7","company_type":1,"uc_number":"9004369","company_subgroup":"7","company_logo":"https://grafana-dashboards-images.s3.amazonaws.com/Logo+FGC+Participa%C3%A7%C3%B5es3.png","supplier":"24","company_group_type":"5","vigency_from":"1900-01-01T00:00:00.000Z","vigency_to":"2023-08-31T00:00:00.000Z","number_uc_consideration":2,"supplier_login":null,"supplier_pass":"v4Xezzd1","supplier_cpf":"","supplier_cnpj":"","supplier_email":"contasapagar@freitasvarejo.com.br","uc_number_2":"9004369","datetime_invoice_emission_day":1,"comercial_company_name":"Empresa - 1007","comercial_subsidiary_name":"Filial - 9237","uuid":"7_6_9004369","city_name":"","supplier_uc_login":"","supplier_cnpj_login":null,"date_update_vigency":"2023-10-31T08:32:02.185Z","invoice_cpf":"","invoice_cnpj":"","invoice_email":"","delay_injection":"0","invoice_end_day":null,"external_id":null,"uuid_external_id":null,"cashback_code":"","vendor_code":"","vendor_type":null,"eh_consumidor":1,"tipo_de_fatura":1,"company_group_type_rural":false,"municipal_inscription":null,"state_inscription":null,"is_trial":false,"af_invoice_history_months":1,"company_supplier_name_registered":null,"supplier_birthday":null,"classificacao_geradora":null,"user_id":null,"company_association_type":null,"kwh_contract":null,"supplier_type":null,"potencia_geradora":null,"active":false,"state_name":"ENEL - Enel Distribuição","company_supplier_name":"CE"},{"id":"133","af_id":1107,"company_id":"133","invoice_start_date":"2021-11-01T00:00:00.000Z","invoice_end_date":"2021-12-01T00:00:00.000Z","datetime_read":null,"dados_fatura":{"grupo":"A","status":"NAOREALIZADA","cliente":"Normatel","subgrupo":"4","cidade_uf":"Cruzeiro - CD","id_fatura":-1,"numero_uc":"9010516","taxa_icms":27,"modalidade":"","updated_at":"2023-08-01T20:02:26.897762+00:00","taxa_cofins":2.78,"data_criacao":"2023-07-06T14:52:35.48096+00:00","data_emissao":"2021-12-09","aws_file_name":"7_133_2021-12_4_6_24_2021-12-01_9010516_-_12.2021.pdf","company_group":7,"ano_referencia":2021,"numero_cliente":"9010516","taxa_pis_pasep":0.62,"datetime_update":"2022-07-25T00:34:22.903584","sistema_horossazonal":"verde","tipo_de_fornecimento":"","numero_mes_referencia":12,"contratou_mercado_livre":false,"valor_distribuidora_cip":392.57,"valor_distribuidora_icms":1861.5,"origem_dos_dados_da_fatura":"","taxa_consumo_fora_ponta_te":0.36473,"valor_distribuidora_cofins":5.99,"taxa_consumo_fora_ponta_tusd":0.47021,"valor_distribuidora_pis_pasep":1.34,"taxa_excedente_ufer_fp_indutivo":0.36469,"valor_distribuidora_descontos_fic_dic_dmic":-125.54,"medicao_distribuidora_consumo_fora_ponta_te":14135,"medicao_distribuidora_consumo_fora_ponta_tusd":14135,"medicao_distribuidora_energia_ativa_ponta_saldo":8691.8,"medicao_distribuidora_excedente_ufer_fp_indutivo":525,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_te":-0.364715,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_te":14035,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":-0.34325,"medicao_distribuidora_energia_ativa_fora_ponta_saldo":18635.8,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":14035,"medicao_distribuidora_energia_ativa_fora_ponta_credito":14035,"m_dist_bandeira_tarifaria_vermelha_fora_ponta_compensado":14035,"medicao_distribuidora_bandeira_tarifaria_vermelha_fora_ponta":14135},"updated_at":"2024-09-21T07:59:36.870Z","rent_calc":true,"af_sync":true,"company_name":"Normatel","subsidiary_name":"Cruzeiro - CD","subsidiary_type":1,"created_at":"2022-03-30T20:00:00.000Z","deleted_at":null,"latitude":null,"longitude":null,"contact_name":null,"contact_phone":null,"contact_address":null,"address":null,"number":null,"complement":null,"district":null,"city_id":null,"state_id":6,"country_id":null,"zip":null,"hour_point_start":"17:30:00","hour_point_end":"20:30:00","hour_hr_start":"21:30:00","hour_hr_end":"06:00:00","company_group":"7","company_type":1,"uc_number":"9010516","company_subgroup":"12","company_logo":"https://grafana-dashboards-images.s3.amazonaws.com/Logo+FGC+Participa%C3%A7%C3%B5es3.png","supplier":"24","company_group_type":"9","vigency_from":"1900-01-01T00:00:00.000Z","vigency_to":"2023-02-01T00:00:00.000Z","number_uc_consideration":2,"supplier_login":null,"supplier_pass":"Brasil01","supplier_cpf":null,"supplier_cnpj":null,"supplier_email":"cristiano.nogueira@normatel.com.br","uc_number_2":"9010516","datetime_invoice_emission_day":1,"comercial_company_name":"Empresa - 1012","comercial_subsidiary_name":"Filial - 9195","uuid":"7_6_9010516","city_name":null,"supplier_uc_login":null,"supplier_cnpj_login":null,"date_update_vigency":null,"invoice_cpf":null,"invoice_cnpj":null,"invoice_email":null,"delay_injection":"0","invoice_end_day":null,"external_id":null,"uuid_external_id":null,"cashback_code":null,"vendor_code":null,"vendor_type":null,"eh_consumidor":null,"tipo_de_fatura":1,"company_group_type_rural":false,"municipal_inscription":null,"state_inscription":null,"is_trial":false,"af_invoice_history_months":1,"company_supplier_name_registered":null,"supplier_birthday":null,"classificacao_geradora":null,"user_id":null,"company_association_type":null,"kwh_contract":null,"supplier_type":null,"potencia_geradora":null,"active":false,"state_name":"ENEL - Enel Distribuição","company_supplier_name":"CE"},{"id":"160","af_id":1110,"company_id":"160","invoice_start_date":"2021-11-01T00:00:00.000Z","invoice_end_date":"2021-12-01T00:00:00.000Z","datetime_read":null,"dados_fatura":{"grupo":"A","status":"NAOREALIZADA","cliente":"McDonalds","subgrupo":"4","cidade_uf":"Maracanaú (B3)","id_fatura":-1,"numero_uc":"49287414","taxa_icms":27,"modalidade":"","updated_at":"2023-08-01T20:02:26.897762+00:00","taxa_cofins":2.78,"data_criacao":"2023-07-06T14:52:35.48096+00:00","data_emissao":"2021-12-15","aws_file_name":"7_160_2021-12_4_6_24_2021-12-01_49287414_-_12.2021.pdf","company_group":7,"ano_referencia":2021,"numero_cliente":"49287414","taxa_pis_pasep":0.62,"datetime_update":"2022-07-25T00:34:22.903584","sistema_horossazonal":"verde","tipo_de_fornecimento":"","numero_mes_referencia":12,"contratou_mercado_livre":false,"valor_distribuidora_cip":199.11,"valor_distribuidora_icms":1897.35,"origem_dos_dados_da_fatura":"","taxa_consumo_fora_ponta_te":0.36473,"valor_distribuidora_cofins":11.63,"taxa_consumo_fora_ponta_tusd":0.4702,"valor_distribuidora_pis_pasep":2.6,"taxa_excedente_ufer_fp_indutivo":0.3647,"medicao_distribuidora_consumo_fora_ponta_te":13827,"medicao_distribuidora_consumo_fora_ponta_tusd":13827,"medicao_distribuidora_energia_ativa_ponta_saldo":8416.89,"medicao_distribuidora_excedente_ufer_fp_indutivo":1286,"taxa_energia_ativa_injetada_fora_ponta_muc_mpt
2,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_tusd":333.2},"updated_at":"2024-09-12T15:03:33.669Z","rent_calc":true,"af_sync":true,"company_name":"Banban","subsidiary_name":"Jurema","subsidiary_type":1,"created_at":"2022-03-30T20:00:00.000Z","deleted_at":"2022-04-01T00:00:00.000Z","latitude":null,"longitude":null,"contact_name":null,"contact_phone":null,"contact_address":null,"address":null,"number":null,"complement":null,"district":null,"city_id":null,"state_id":6,"country_id":null,"zip":null,"hour_point_start":"17:30:00","hour_point_end":"20:30:00","hour_hr_start":"21:30:00","hour_hr_end":"06:00:00","company_group":"7","company_type":1,"uc_number":"49728572","company_subgroup":"2","company_logo":"https://grafana-dashboards-images.s3.amazonaws.com/Logo+FGC+Participa%C3%A7%C3%B5es3.png","supplier":"24","company_group_type":"5","vigency_from":"1900-01-01T00:00:00.000Z","vigency_to":"2022-04-01T00:00:00.000Z","number_uc_consideration":2,"supplier_login":null,"supplier_pass":null,"supplier_cpf":null,"supplier_cnpj":null,"supplier_email":null,"uc_number_2":"49728572","datetime_invoice_emission_day":8,"comercial_company_name":"Empresa - 1002","comercial_subsidiary_name":"Filial - 1187","uuid":"del_7_6_49728572","city_name":null,"supplier_uc_login":null,"supplier_cnpj_login":null,"date_update_vigency":null,"invoice_cpf":null,"invoice_cnpj":null,"invoice_email":null,"delay_injection":"0","invoice_end_day":null,"external_id":null,"uuid_external_id":null,"cashback_code":null,"vendor_code":null,"vendor_type":null,"eh_consumidor":null,"tipo_de_fatura":null,"company_group_type_rural":false,"municipal_inscription":null,"state_inscription":null,"is_trial":false,"af_invoice_history_months":1,"company_supplier_name_registered":null,"supplier_birthday":null,"classificacao_geradora":null,"user_id":null,"company_association_type":null,"kwh_contract":null,"supplier_type":null,"potencia_geradora":null,"active":false,"state_name":"ENEL - Enel Distribuição","company_supplier_name":"CE"},{"id":"82","af_id":965,"company_id":"82","invoice_start_date":"2021-11-01T00:00:00.000Z","invoice_end_date":"2021-12-01T00:00:00.000Z","datetime_read":null,"dados_fatura":{"grupo":"A","status":"NAOREALIZADA","cliente":"Banban","subgrupo":"4","cidade_uf":"Maracanaú","id_fatura":-1,"numero_uc":"9005520","taxa_icms":27,"modalidade":"","updated_at":"2023-08-01T20:02:26.897762+00:00","taxa_cofins":2.78,"data_criacao":"2023-07-06T14:52:35.48096+00:00","data_emissao":"2021-12-06","aws_file_name":"7_82_2021-12_4_6_24_2021-12-01_9005520_-_12.2021.pdf","company_group":7,"ano_referencia":2021,"numero_cliente":"9005520","taxa_pis_pasep":0.62,"datetime_update":"2022-07-25T00:34:22.903584","sistema_horossazonal":"verde","tipo_de_fornecimento":"","numero_mes_referencia":12,"taxa_consumo_ponta_te":0.56153,"contratou_mercado_livre":false,"taxa_consumo_ponta_tusd":1.6978,"valor_distribuidora_cip":199.11,"valor_distribuidora_icms":1650.96,"origem_dos_dados_da_fatura":"","taxa_consumo_fora_ponta_te":0.34683,"valor_distribuidora_cofins":27.58,"taxa_consumo_fora_ponta_tusd":0.08538,"valor_distribuidora_pis_pasep":6.15,"taxa_excedente_ufer_fp_indutivo":0.36393,"taxa_demanda_fora_ponta_indutivo":27,"medicao_distribuidora_consumo_ponta_te":2269,"taxa_demanda_fora_ponta_indutivo_s_icms":19.70982,"medicao_distribuidora_consumo_ponta_tusd":2269,"valor_distribuidora_acrescimo_cip_multas":-0.08,"medicao_distribuidora_consumo_fora_ponta_te":11982,"taxa_bandeira_tarifaria_vermelha_fora_ponta":1,"taxa_energia_ativa_injetada_ponta_ouc_mpt_te":-0.560845,"taxa_energia_ativa_injetada_ponta_ouc_opt_te":-0.56134,"medicao_distribuidora_consumo_fora_ponta_tusd":11982,"taxa_energia_ativa_injetada_ponta_ouc_mpt_tusd":-1.239585,"taxa_energia_ativa_injetada_ponta_ouc_opt_tusd":-1.23952,"medicao_distribuidora_excedente_ufer_fp_indutivo":28,"medicao_distribuidora_demanda_fora_ponta_indutivo":45.52,"medicao_distribuidora_energia_ativa_ponta_credito":3407,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_te":-0.34674,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_te":11982,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":-0.062295,"medicao_distribuidora_energia_ativa_fora_ponta_saldo":63673.71,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":11982,"medicao_distribuidora_energia_ativa_fora_ponta_credito":11982,"taxa_bandeira_tarifaria_vermelha_fora_ponta_compensado":1,"m_dist_bandeira_tarifaria_vermelha_fora_ponta_compensado":-2869.63,"medicao_distribuidora_demanda_fora_ponta_indutivo_s_icms":4.48,"medicao_distribuidora_bandeira_tarifaria_vermelha_fora_ponta":2869.64,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_te":430.2,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_opt_te":1838.799,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_tusd":430.2,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_opt_tusd":1838.799},"updated_at":"2024-09-12T15:03:33.669Z","rent_calc":true,"af_sync":true,"company_name":"Banban","subsidiary_name":"Maracanaú","subsidiary_type":1,"created_at":"2022-03-30T20:00:00.000Z","deleted_at":"2022-04-01T00:00:00.000Z","latitude":null,"longitude":null,"contact_name":null,"contact_phone":null,"contact_address":null,"address":null,"number":null,"complement":null,"district":null,"city_id":null,"state_id":6,"country_id":null,"zip":null,"hour_point_start":"17:30:00","hour_point_end":"20:30:00","hour_hr_start":"21:30:00","hour_hr_end":"06:00:00","company_group":"7","company_type":1,"uc_number":"9005520","company_subgroup":"2","company_logo":"https://grafana-dashboards-images.s3.amazonaws.com/Logo+FGC+Participa%C3%A7%C3%B5es3.png","supplier":"24","company_group_type":"5","vigency_from":"1900-01-01T00:00:00.000Z","vigency_to":"2022-04-01T00:00:00.000Z","number_uc_consideration":2,"supplier_login":null,"supplier_pass":null,"supplier_cpf":null,"supplier_cnpj":null,"supplier_email":null,"uc_number_2":"9005520","datetime_invoice_emission_day":19,"comercial_company_name":"Empresa - 1002","comercial_subsidiary_name":"Filial - 9357","uuid":"del_7_6_9005520","city_name":null,"supplier_uc_login":null,"supplier_cnpj_login":null,"date_update_vigency":null,"invoice_cpf":null,"invoice_cnpj":null,"invoice_email":null,"delay_injection":"0","invoice_end_day":null,"external_id":null,"uuid_external_id":null,"cashback_code":null,"vendor_code":null,"vendor_type":null,"eh_consumidor":null,"tipo_de_fatura":null,"company_group_type_rural":false,"municipal_inscription":null,"state_inscription":null,"is_trial":false,"af_invoice_history_months":1,"company_supplier_name_registered":null,"supplier_birthday":null,"classificacao_geradora":null,"user_id":null,"company_association_type":null,"kwh_contract":null,"supplier_type":null,"potencia_geradora":null,"active":false,"state_name":"ENEL - Enel Distribuição","company_supplier_name":"CE"},{"id":"93","af_id":969,"company_id":"93","invoice_start_date":"2021-11-01T00:00:00.000Z","invoice_end_date":"2021-12-01T00:00:00.000Z","datetime_read":null,"dados_fatura":{"grupo":"A","status":"NAOREALIZADA","cliente":"Farias Brito","subgrupo":"4","cidade_uf":"Senador Pompeu","id_fatura":-1,"numero_uc":"768834","taxa_icms":27,"modalidade":"","updated_at":"2023-08-01T20:02:26.897762+00:00","taxa_cofins":2.78,"data_criacao":"2023-07-06T14:52:35.48096+00:00","data_emissao":"2021-12-09","aws_file_name":"7_93_2021-12_4_6_24_2021-12-01_768834_-_12.2021.pdf","company_group":7,"ano_referencia":2021,"numero_cliente":"768834","taxa_pis_pasep":0.62,"datetime_update":"2022-07-25T00:34:22.903584","sistema_horossazonal":"verde","tipo_de_fornecimento":"","numero_mes_referencia":12,"taxa_consumo_ponta_te":0.56154,"contratou_mercado_livre":false,"taxa_consumo_ponta_tusd":1.6978,"valor_distribuidora_cip":392.57,"valor_distribuidora_icms":5279.2,"taxa_excedente_ufer_ponta":0.3647,"origem_dos_dados_da_fatura":"","taxa_consumo_fora_ponta_te":0.34683,"valor_distribuidora_cofins":213.39,"taxa_consumo_fora_ponta_tusd":0.08538,"valor_distribuidora_pis_pasep":47.59,"taxa_excedente_ufer_fp_indutivo":0.36467,"taxa_demanda_fora_ponta_indutivo":27.0001,"medicao_distribuidora_consumo_ponta_te":3039,"taxa_demanda_ultrapassagem_hfp_indutivo":53.99945,"medicao_distribuidora_consumo_ponta_tusd":3039,"medicao_distribuidora_excedente_ufer_ponta":200,"medicao_distribuidora_consumo_fora_ponta_te":45410,"taxa_bandeira_tarifaria_vermelha_fora_ponta":1,"taxa_energia_ativa_injetada_ponta_ouc_mpt_te":-0.56087,"medicao_distribuidora_consumo_fora_ponta_tusd":45410,"taxa_energia_ativa_injetada_ponta_ouc_mpt_tusd":-1.2396,"medicao_distribuidora_energia_ativa_ponta_saldo":21515.7,"medicao_distribuidora_excedente_ufer_fp_indutivo":516,"medicao_distribuidora_demanda_fora_ponta_indutivo":306.6,"medicao_distribuidora_energia_ativa_ponta_credito":3039,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_te":-0.34674,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_te":45410,"medicao_distribuidora_est_liminar_isen_icms_demanda":-2768.74,"taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":-0.062295,"medicao_distribuidora_energia_ativa_fora_ponta_saldo":127720.8,"m_dist_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd":45410,"medicao_distribuidora_energia_ativa_fora_ponta_credito":45410,"taxa_bandeira_tarifaria_vermelha_fora_ponta_compensado":1,"m_dist_bandeira_tarifaria_vermelha_fora_ponta_compensado":-9755.96,"medicao_distribuidora_demanda_ultrapassagem_hfp_indutivo":36.6,"medicao_distribuidora_bandeira_tarifaria_vermelha_fora_ponta":9756,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_te":3039,"medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_tusd":3039},"updated_at":"2024-09-21T07:59:36.870Z","rent_calc":true,"af_sync":true,"company_name":"Farias Brito","subsidiary_name":"Senador Pompeu","subsidiary_type":null,"created_at":"2024-09-09T19:45:28.300Z","deleted_at":null,"latitude":null,"longitude":null,"contact_name":null,"contact_phone":"","contact_address":null,"address":"","number":"0","complement":"","district":"","city_id":null,"state_id":6,"country_id":1,"zip":null,"hour_point_start":null,"hour_point_end":null,"hour_hr_start":null,"hour_hr_end":null,"company_group":"7","company_type":1,"uc_number":"768834","company_subgroup":"4","company_logo":null,"supplier":"24","company_group_type":"5","vigency_from":"2022-05-01T00:00:00.000Z","vigency_to":"2999-12-31T00:00:00.000Z","number_uc_consideration":2,"supplier_login":null,"supplier_pass":"bDd5BXtg","supplier_cpf":null,"supplier_cnpj":"74000738000195","supplier_email":"contratos@fariasbrito.com.br","uc_number_2":"768834","datetime_invoice_emission_day":1,"comercial_company_name":null,"comercial_subsidiary_name":null,"uuid":"7_6_768834","city_name":"","supplier_uc_login":null,"supplier_cnpj_login":null,"date_update_vigency":null,"invoice_cpf":null,"invoice_cnpj":"74000738000195","invoice_email":"","delay_injection":null,"invoice_end_day":null,"external_id":null,"uuid_external_id":null,"cashback_code":null,"vendor_code":null,"vendor_type":1,"eh_consumidor":1,"tipo_de_fatura":1,"company_group_type_rural":false,"municipal_inscription":null,"state_inscription":null,"is_trial":false,"af_invoice_history_months":1,"company_supplier_name_registered":null,"supplier_birthday":null,"classificacao_geradora":null,"user_id":"365","company_association_type":null,"kwh_contract":null,"supplier_type":null,"potencia_geradora":0,"active":true,"state_name":"ENEL - Enel Distribuição","company_supplier_name":"CE"},{"id":"75","af_id":812,"company_id":"75","invoice_start_date":"2021-11-01T00:00:00.000Z","invoice_end_date":"2021-12-01T00:00:00.000Z","datetime_read":null,"dados_fatura":{"grupo":"A","status":"NAOREALIZADA","cliente":"Maj Facundo","subgrupo":"4","cidade_uf":"ceare/ce","id_fatura":-1,"numero_uc":"","taxa_icms":0.27,"modalidade":"","updated_at":"2023-08-01T20:02:26.897762+00:00","taxa_cofins":0.0278,"data_criacao":"2023-07-06T14:52:35.48096+00:00","aws_file_name":"","company_group":7,"ano_referencia":2021,"numero_cliente":"","taxa_pis_pasep":0.0062,"datetime_update":"2022-07-25T00:34:22.903584","sistema_horossazonal":"verde","tipo_de_fornecimento":"","numero_mes_referencia":12,"taxa_consumo_ponta_te":0.56152,"contratou_mercado_livre":false,"taxa_consumo_ponta_tusd":1.69779,"valor_distribuidora_icms":667.37,"taxa_excedente_ufer_ponta":0.35831,"origem_dos_dados_da_fatura":"","taxa_consumo_fora_ponta_te":0.34683,"valor_distribuidora_cofins":27.96,"taxa_consumo_fora_ponta_tusd":0.08538,"valor_distribuidora_pis_pasep":6.24,"taxa_excedente_ufer_fp_indutivo":0.36438,"taxa_demanda_fora_ponta_indutivo":27.00303,"medicao_distribuidora_consumo_ponta_te":476.625,"taxa_demanda_fora_ponta_indutivo_s_icms":19.71814,"medicao_distribuidora_consumo_ponta_tusd":476.625,"valor_distribuidora_acrescimo_cip_multas":392.57,"medicao_distribuidora_excedente_ufer_ponta":3.075,"medicao_distribuidora_consumo_fora_ponta_te":7700.825,"taxa_bandeira_tarifaria_vermelha_fora_ponta":1,"taxa_energia_ativa_injetada_ponta_ouc_mpt_te":-0.
"medicao_distribuidora_energia_ativa_injetada_ponta_muc_mpt_tusd":3920,"medicao_distribuidora_energia_ativa_injetada_ponta_muc_opt_tusd":1815},"updated_at":"2024-09-21T07:59:36.870Z","rent_calc":true,"af_sync":true,"company_name":"Normatel","subsidiary_name":"Eusébio","subsidiary_type":1,"created_at":"2022-03-30T20:00:00.000Z","deleted_at":null,"latitude":null,"longitude":null,"contact_name":null,"contact_phone":null,"contact_address":null,"address":null,"number":null,"complement":null,"district":null,"city_id":null,"state_id":6,"country_id":null,"zip":null,"hour_point_start":"17:30:00","hour_point_end":"20:30:00","hour_hr_start":"21:30:00","hour_hr_end":"06:00:00","company_group":"7","company_type":1,"uc_number":"50310638","company_subgroup":"12","company_logo":"https://grafana-dashboards-images.s3.amazonaws.com/Logo+FGC+Participa%C3%A7%C3%B5es3.png","supplier":"24","company_group_type":"5","vigency_from":"1900-01-01T00:00:00.000Z","vigency_to":"2023-02-01T00:00:00.000Z","number_uc_consideration":2,"supplier_login":null,"supplier_pass":"Brasil01","supplier_cpf":null,"supplier_cnpj":null,"supplier_email":"cristiano.nogueira@normatel.com.br","uc_number_2":"50310638","datetime_invoice_emission_day":1,"comercial_company_name":"Empresa - 1012","comercial_subsidiary_name":"Filial - 5049","uuid":"7_6_50310638","city_name":null,"supplier_uc_login":null,"supplier_cnpj_login":null,"date_update_vigency":null,"invoice_cpf":null,"invoice_cnpj":null,"invoice_email":null,"delay_injection":"0","invoice_end_day":null,"external_id":null,"uuid_external_id":null,"cashback_code":null,"vendor_code":null,"vendor_type":null,"eh_consumidor":null,"tipo_de_fatura":1,"company_group_type_rural":false,"municipal_inscription":null,"state_inscription":null,"is_trial":false,"af_invoice_history_months":1,"company_supplier_name_registered":null,"supplier_birthday":null,"classificacao_geradora":null,"user_id":null,"company_association_type":null,"kwh_contract":null,"supplier_type":null,"potencia_geradora":null,"active":false,"state_name":"ENEL - Enel Distribuição","company_supplier_name":"CE"}]

'''

# %%
import ast
import pandas as pd

data.replace('\\\\', '**')
data.replace('\\', '*')
data.replace('null', 'None')
data.replace('false', 'False')
data.replace('true', 'True')

# Tentar carregar os dados JSON
try:
    data_list = json.loads(data)
except json.JSONDecodeError as e:
    print(f"Erro ao carregar o JSON: {e}")
    # Exibir a parte do JSON onde o erro está ocorrendo
    pos = e.pos
    print(f"Problema no caractere {pos}: '{data[pos-20:pos+20]}'")
    raise

# Se o JSON for carregado corretamente, normalizar os dados em um DataFrame
if 'data_list' in locals():
    df = pd.json_normalize(data_list)

    # Remover o prefixo 'dados_fatura.' das colunas, se necessário
    #df.columns = df.columns.str.replace('dados_fatura.', '', regex=False)

    # Exibir o DataFrame
    df.head()

# %%
df.shape
# Out:
# (72, 184)

# %%
df.columns
# Out:
# Index(['id', 'af_id', 'company_id', 'invoice_start_date', 'invoice_end_date',
#        'datetime_read', 'updated_at', 'rent_calc', 'af_sync', 'company_name',
#        ...
#        'dados_fatura.medicao_distribuidora_energia_injetada_hp',
#        'dados_fatura.medicao_distribuidora_energia_injetada_hfp',
#        'dados_fatura.taxa_custo_disponib_ren_482_12_te',
#        'dados_fatura.valor_custo_disponib_ren_482_12_te',
#        'dados_fatura.taxa_custo_disponib_ren_482_12_tusd',
#        'dados_fatura.valor_custo_disponib_ren_482_12_tusd',
#        'dados_fatura.taxa_excedente_ufdr_fp_indutivo',
#        'dados_fatura.medicao_distribuidora_excedente_ufdr_fp_indutivo',
#        'dados_fatura.pagamento_duplicidade',
#        'dados_fatura.valor_distribuidora_conexao_distribuicao'],
#       dtype='object', length=193)

# %%
df.head(2)
# Out:
#     id  af_id company_id        invoice_start_date          invoice_end_date  \
# 0   98   1537         98  2022-02-01T00:00:00.000Z  2022-03-01T00:00:00.000Z
# 1  111   2191        111  2022-05-01T00:00:00.000Z  2022-06-01T00:00:00.000Z
#
#   datetime_read                updated_at  rent_calc  af_sync    company_name  \
# 0          None  2024-09-21T07:59:36.870Z       True     True    Farias Brito
# 1          None  2024-09-21T07:59:36.870Z       True     True  Freitas Varejo
#
#    ... dados_fatura.medicao_distribuidora_energia_injetada_hp  \
# 0  ...                                                NaN
# 1  ...                                                NaN
#
#    dados_fatura.medicao_distribuidora_energia_injetada_hfp  \
# 0                                                NaN
# 1                                                NaN
#
#   dados_fatura.taxa_custo_disponib_ren_482_12_te  \
# 0                                            NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'af_id', 'company_id', 'invoice_start_date', 'invoice_end_date',
#        'datetime_read', 'updated_at', 'rent_calc', 'af_sync', 'company_name',
#        ...
#        'med_dist_energia_ativa_injetada_fora_ponta_ouc_opt_tusd',
#        'valor_distribuidora_descontos_fic_dic_dmic',
#        'valor_distribuidora_ecoenel',
#        'taxa_energia_ativa_injetada_fora_ponta_muc_opt_te',
#        'taxa_energia_ativa_injetada_fora_ponta_muc_opt_tusd',
#        'med_dist_energia_ativa_injetada_fora_ponta_muc_opt_te',
#        'med_dist_energia_ativa_injetada_fora_ponta_muc_opt_tusd',
#        'desligamento_programado', 'taxa_excedente_ufdr_fp_indutivo',
#        'medicao_distribuidora_excedente_ufdr_fp_indutivo'],
#       dtype='object', length=185)

# %%
df.to_parquet('../Documentos/df_cogni_2021.parquet', engine='pyarrow')

# %%
import pandas as pd

df_cogni_2021 = pd.read_parquet('../energy_demand_prediction/df_cogni_2021.parquet', engine='pyarrow')
df_cogni_2021
# Out:
#      id  af_id company_id        invoice_start_date          invoice_end_date  \
# 0   113    998        113  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 1   133   1107        133  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 2   160   1110        160  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 3   216   2087        216  2021-04-01T00:00:00.000Z  2021-05-01T00:00:00.000Z
# 4   115   1002        115  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# ..  ...    ...        ...                       ...                       ...
# 67  158   1051        158  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 68  100    983        100  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 69  104    991        104  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 70  129   1020        129  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 71  135   1032        135  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
#
# ...

# %%
import pandas as pd

# Now retry loading the parquet files and checking column differences

df_2021 = pd.read_parquet('../energy_demand_prediction/df_cogni_2021.parquet', engine='pyarrow')
df_2022 = pd.read_parquet('../energy_demand_prediction/df_cogni_2022.parquet', engine='pyarrow')
df_2023 = pd.read_parquet('../energy_demand_prediction/df_cogni_2023.parquet', engine='pyarrow')
df_2024 = pd.read_parquet('../energy_demand_prediction/df_cogni_2024.parquet', engine='pyarrow')

# Get the set of columns for each DataFrame
columns_2021 = set(df_2021.columns)
columns_2022 = set(df_2022.columns)
columns_2023 = set(df_2023.columns)
columns_2024 = set(df_2024.columns)

# Find columns that are unique to each year
unique_to_2021 = columns_2021 - (columns_2022 | columns_2023 | columns_2024)
unique_to_2022 = columns_2022 - (columns_2021 | columns_2023 | columns_2024)
unique_to_2023 = columns_2023 - (columns_2021 | columns_2022 | columns_2024)
unique_to_2024 = columns_2024 - (columns_2021 | columns_2022 | columns_2023)

# Find common columns
common_columns = columns_2021 & columns_2022 & columns_2023 & columns_2024

# Prepare results
results = {
    'unique_to_2021': unique_to_2021,
    'unique_to_2022': unique_to_2022,
    'unique_to_2023': unique_to_2023,
    'unique_to_2024': unique_to_2024,
    'common_columns': common_columns
}

results
# Out:
# {'unique_to_2021': {'dados_fatura.base_calculo_distribuidora',
#   'dados_fatura.consumo_medio_diario_kwh',
#   'dados_fatura.custo_medio_da_energia_eletrica',
#   'dados_fatura.m_dist_bandeira_tarifaria_vermelha_ponta_compensado',
#   'dados_fatura.medicao_distribuidora_bandeira_tarifaria_vermelha_ponta',
#   'dados_fatura.medicao_distribuidora_consumo_total_kwh',
#   'dados_fatura.multa_por_excedente_reativo',
#   'dados_fatura.percentual_uso_da_energia_eletrica_horario_ponta',
#   'dados_fatura.taxa_bandeira_tarifaria_vermelha_ponta',
#   'dados_fatura.taxa_bandeira_tarifaria_vermelha_ponta_compensado',
#   'dados_fatura.total_cogni_v_calc_consumo',
#   'dados_fatura.total_cogni_v_calc_consumo_com_impostos',
#   'dados_fatura.total_cogni_v_calc_demanda_com_impostos',
#   'dados_fatura.total_fatura'},
#  'unique_to_2022': {'dados_fatura.medicao_distribuidora_energia_injetada_hfp',
#   'dados_fatura.medicao_distribuidora_energia_injetada_hp',
# ...

# %%
# Convert common_columns set to a list for use in the merge
common_columns_list = list(common_columns)

# Filter each DataFrame to only keep the common columns
df_2021_common = df_2021[common_columns_list]
df_2022_common = df_2022[common_columns_list]
df_2023_common = df_2023[common_columns_list]
df_2024_common = df_2024[common_columns_list]

# Perform the merges on the common columns
df_merged = df_2021_common.merge(df_2022_common, on=common_columns_list)
df_merged = df_merged.merge(df_2023_common, on=common_columns_list)
df_merged = df_merged.merge(df_2024_common, on=common_columns_list)

# Show the first few rows of the merged DataFrame
df_merged.head()
# Out:
# Empty DataFrame
# ...

# %%
# Convert all columns in each DataFrame to strings
df_2021_common = df_2021[common_columns_list].astype(str)
df_2022_common = df_2022[common_columns_list].astype(str)
df_2023_common = df_2023[common_columns_list].astype(str)
df_2024_common = df_2024[common_columns_list].astype(str)

# Perform the merge after converting all data to strings
df_merged = df_2024_common.merge(df_2023_common, on=common_columns_list, how='left')
df_merged = df_merged.merge(df_2022_common, on=common_columns_list, how='left')
df_merged = df_merged.merge(df_2021_common, on=common_columns_list, how='left')

# Show the first few rows of the merged DataFrame
df_merged.head()
# Out:
#   dados_fatura.taxa_energia_ativa_injetada_ponta_muc_mpt_te   supplier_cnpj  \
# 0                                           -0.57918         03720882000158
# 1                                           -0.61711         07240641000162
# 2                                                nan         74000738000195
# 3                                           -0.60835         03720882000158
# 4                                           -0.61695         12369179000138
#
#   dados_fatura.taxa_excedente_ufer_ponta dados_fatura.sistema_horossazonal  \
# 0                                0.37877                             verde
# 1                                    nan                             verde
# 2                                    nan                             verde
# 3                                    nan                             verde
# 4                                0.39911                             verde
#
# ...

# %%
df_merged['id'] = df_merged['id'].astype('Int64')

# %%
# columns to drop = 'city_id', 'eh_consumidor', 'is_trial', 'municipal_inscription', 'supplier_login', 
# 'supplier_cpf', 'contact_name', ' 'uuid_external_id','company_logo',
df_merged['subsidiary_name'].value_counts(dropna=False)
# Out:
# Beberibe-CE            103
# Aquiraz-CE              96
# Atlântico               66
# Eusébio                 63
# Washington Soares       59
#                       ...
# LOJA 49                  1
# Dionisio Torres          1
# Dom Expedito             1
# Tamatanduba Eusebio      1
# LOJA 44                  1
# Name: subsidiary_name, Length: 183, dtype: int64

# %%
# Convert the specific common columns to strings to ensure consistent data types
def convert_common_columns_to_str(df, columns):
    for col in columns:
        df[col] = df[col].astype(str)
    return df

# List of common columns to merge on
common_columns_list = list(common_columns)  # Assuming 'common_columns' contains the right columns

# Apply the conversion to each DataFrame
df_2021_clean = convert_common_columns_to_str(df_2021, common_columns_list)
df_2022_clean = convert_common_columns_to_str(df_2022, common_columns_list)
df_2023_clean = convert_common_columns_to_str(df_2023, common_columns_list)
df_2024_clean = convert_common_columns_to_str(df_2024, common_columns_list)

# Now perform the merge after ensuring the types are consistent
df_merged = df_2021_clean.merge(df_2022_clean, on=common_columns_list, how='outer')
df_merged = df_merged.merge(df_2023_clean, on=common_columns_list, how='outer')
df_merged = df_merged.merge(df_2024_clean, on=common_columns_list, how='outer')

# Show the merged DataFrame
df_merged.shape
# Out:
# (3397, 271)

# %%
# Assuming 'id' is the column to group by
df_grouped = df_merged.groupby('id').first().reset_index()

# Show the resulting grouped DataFrame
df_grouped.shape
# Out:
# (201, 271)

# %%
df_grouped['dados_fatura.data_criacao'].dtype#.dt.month.value_counts(dropna=False)
# Out:
# dtype('O')

# %%
# Concatenate the DataFrames along rows
df_concat = pd.concat([df_2021, df_2022, df_2023, df_2024], axis=0, ignore_index=True)

# Show the concatenated DataFrame
df_concat.shape
# Out:
# (3397, 216)

# %%
df_2021 = pd.read_parquet('../energy_demand_prediction/df_cogni_2021.parquet', engine='pyarrow')
df_2022 = pd.read_parquet('../energy_demand_prediction/df_cogni_2022.parquet', engine='pyarrow')
df_2023 = pd.read_parquet('../energy_demand_prediction/df_cogni_2023.parquet', engine='pyarrow')
df_2024 = pd.read_parquet('../energy_demand_prediction/df_cogni_2024.parquet', engine='pyarrow')

# Convert all columns in each DataFrame to strings
df_2021_common = df_2021[common_columns_list].astype(str)
df_2022_common = df_2022[common_columns_list].astype(str)
df_2023_common = df_2023[common_columns_list].astype(str)
df_2024_common = df_2024[common_columns_list].astype(str)

def treat_yearly_data(df):
    # Standardize column types: treat specific columns according to their type
    string_columns = [
        'company_group', 'invoice_cpf', 'comercial_subsidiary_name', 
        'contact_phone', 'company_supplier_name_registered', 'uuid', 'supplier_cnpj_login',
        'supplier_uc_login', 'subsidiary_name', 'comercial_company_name'
    ]

    numeric_columns = [
        'dados_fatura.valor_multas_e_juros', 'dados_fatura.taxa_consumo_ponta_te', 'id', 'number',
        'dados_fatura.taxa_energia_ativa_injetada_ponta_muc_opt_tusd', 'dados_fatura.taxa_demanda_fora_ponta_indutivo'
    ]

    datetime_columns = [
        'dados_fatura.data_criacao', 'dados_fatura.data_emissao', 'date_update_vigency', 'vigency_from', 'vigency_to'
    ]

    boolean_columns = ['active', 'eh_consumidor', 'is_trial']

    # Convert string columns to string
    df[string_columns] = df[string_columns].astype(str)

    # Convert numeric columns to numeric
    df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

    # Convert datetime columns to datetime
    df[datetime_columns] = df[datetime_columns].apply(pd.to_datetime, errors='coerce')

    # Convert boolean columns to boolean
    df[boolean_columns] = df[boolean_columns].astype(bool)

    # Return the treated DataFrame
    return df

# Apply the function to each year's DataFrame
df_2021_clean = treat_yearly_data(df_2021)
df_2022_clean = treat_yearly_data(df_2022)
df_2023_clean = treat_yearly_data(df_2023)
df_2024_clean = treat_yearly_data(df_2024)

# Now the data types across all years are consistent
# Out:
# /var/folders/gm/cmbnr1k149zck2cgb18s0t_40000gn/T/ipykernel_18081/295550911.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[datetime_columns] = df[datetime_columns].apply(pd.to_datetime, errors='coerce')
# /var/folders/gm/cmbnr1k149zck2cgb18s0t_40000gn/T/ipykernel_18081/295550911.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[datetime_columns] = df[datetime_columns].apply(pd.to_datetime, errors='coerce')
# /var/folders/gm/cmbnr1k149zck2cgb18s0t_40000gn/T/ipykernel_18081/295550911.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
df_2021_clean
# Out:
#      id  af_id company_id        invoice_start_date          invoice_end_date  \
# 0   113    998        113  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 1   133   1107        133  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 2   160   1110        160  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 3   216   2087        216  2021-04-01T00:00:00.000Z  2021-05-01T00:00:00.000Z
# 4   115   1002        115  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# ..  ...    ...        ...                       ...                       ...
# 67  158   1051        158  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 68  100    983        100  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 69  104    991        104  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 70  129   1020        129  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
# 71  135   1032        135  2021-11-01T00:00:00.000Z  2021-12-01T00:00:00.000Z
#
# ...

# %%
print(df_2021_clean.shape)
print(df_2022_clean.shape)
print(df_2023_clean.shape)
print(df_2024_clean.shape)
# Out:
# (72, 184)
# (1387, 193)
# (1176, 189)
# (762, 185)

# %%
# Obter as colunas de cada DataFrame
columns_2021 = set(df_2021_clean.columns)
columns_2022 = set(df_2022_clean.columns)
columns_2023 = set(df_2023_clean.columns)
columns_2024 = set(df_2024_clean.columns)

# Encontrar a interseção (colunas em comum) entre todos os DataFrames
common_columns = columns_2021 & columns_2022 & columns_2023 & columns_2024

# Mostrar as colunas em comum
#print(f"Colunas em comum entre todos os DataFrames ({len(common_columns)} colunas):")
#print(common_columns)

# %%
# Convert problematic columns to consistent types
# Convert 'dados_fatura.taxa_icms' to float
for col in ['dados_fatura.taxa_icms']:
    df_2021_common[col] = df_2021_common[col].astype(float)
    df_2022_common[col] = df_2022_common[col].astype(float)
    df_2023_common[col] = df_2023_common[col].astype(float)
    df_2024_common[col] = df_2024_common[col].astype(float)

# Convert 'latitude' and 'longitude' to float
for col in ['latitude', 'longitude']:
    df_2021_common[col] = df_2021_common[col].astype(float)
    df_2022_common[col] = df_2022_common[col].astype(float)
    df_2023_common[col] = df_2023_common[col].astype(float)
    df_2024_common[col] = pd.to_numeric(df_2024_common[col], errors='coerce')

# Convert 'tipo_de_fatura', 'classificacao_geradora', and 'supplier_type' to str
for col in ['tipo_de_fatura', 'classificacao_geradora', 'supplier_type']:
    df_2021_common[col] = df_2021_common[col].astype(str)
    df_2022_common[col] = df_2022_common[col].astype(str)
    df_2023_common[col] = df_2023_common[col].astype(str)
    df_2024_common[col] = df_2024_common[col].astype(str)



# Filtrar os DataFrames para conter apenas as colunas em comum
df_2021_common = df_2021_clean[list(common_columns)]
df_2022_common = df_2022_clean[list(common_columns)]
df_2023_common = df_2023_clean[list(common_columns)]
df_2024_common = df_2024_clean[list(common_columns)]

# Fazer o merge dos DataFrames usando as colunas em comum
df_merged = df_2021_common.merge(df_2022_common, on=list(common_columns), how='outer')
df_merged = df_merged.merge(df_2023_common, on=list(common_columns), how='outer')
df_merged = df_merged.merge(df_2024_common, on=list(common_columns), how='outer')

# Verificar o resultado
df_merged.head()
# Out:
# /var/folders/gm/cmbnr1k149zck2cgb18s0t_40000gn/T/ipykernel_18081/4174219828.py:33: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df_merged = df_merged.merge(df_2023_common, on=list(common_columns), how='outer')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 34
#      32 df_merged = df_2021_common.merge(df_2022_common, on=list(common_columns), how='outer')
#      33 df_merged = df_merged.merge(df_2023_common, on=list(common_columns), how='outer')
# ---> 34 df_merged = df_merged.merge(df_2024_common, on=list(common_columns), how='outer')
#      36 # Verificar o resultado
#      37 df_merged.head()
#
# ...

# %%
# Ensure the columns in common have the same data type
# For numeric columns (e.g., float64, int64), convert to float
numeric_columns = ['dados_fatura.taxa_icms', 'latitude', 'longitude']  # Add any other numeric columns

for col in numeric_columns:
    df_2021_common[col] = pd.to_numeric(df_2021_common[col], errors='coerce')
    df_2022_common[col] = pd.to_numeric(df_2022_common[col], errors='coerce')
    df_2023_common[col] = pd.to_numeric(df_2023_common[col], errors='coerce')
    df_2024_common[col] = pd.to_numeric(df_2024_common[col], errors='coerce')

# For string columns (e.g., object), convert to str
string_columns = ['tipo_de_fatura', 'classificacao_geradora', 'supplier_type']  # Add any other string columns

for col in string_columns:
    df_2021_common[col] = df_2021_common[col].astype(str)
    df_2022_common[col] = df_2022_common[col].astype(str)
    df_2023_common[col] = df_2023_common[col].astype(str)
    df_2024_common[col] = df_2024_common[col].astype(str)


# Now retry the merge after ensuring data type consistency
df_merged = df_2021_common.merge(df_2022_common, on=list(common_columns), how='outer')
df_merged = df_merged.merge(df_2023_common, on=list(common_columns), how='outer')
df_merged = df_merged.merge(df_2024_common, on=list(common_columns), how='outer')

# Display the result
df_merged.head()
# Out:
# /var/folders/gm/cmbnr1k149zck2cgb18s0t_40000gn/T/ipykernel_18081/1149323163.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_common[col] = pd.to_numeric(df_2021_common[col], errors='coerce')
# /var/folders/gm/cmbnr1k149zck2cgb18s0t_40000gn/T/ipykernel_18081/1149323163.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_common[col] = pd.to_numeric(df_2022_common[col], errors='coerce')
# ...

# %%
df_merged
# Out:
#       dados_fatura.taxa_energia_ativa_injetada_ponta_muc_mpt_te  \
# 0                                             -0.676910
# 1                                             -0.676910
# 2                                             -0.676900
# 3                                             -0.676805
# 4                                             -0.676670
# ...                                                 ...
# 3392                                                NaN
# 3393                                                NaN
# 3394                                                NaN
# 3395                                                NaN
# 3396                                                NaN
#
#            supplier_cnpj  dados_fatura.taxa_excedente_ufer_ponta  \
# 0         74000738000195                                 0.44148
# 1         74000738000195                                     NaN
# 2                   None                                     NaN
# ...

# %%
#pip install ydata-profiling

# %%
# from ydata_profiling import ProfileReport

# # Gerar o relatório
# profile = ProfileReport(df_merged, title="Relatório do DataFrame Merged", explorative=True)

# # Visualizar no Jupyter Notebook
# profile.to_notebook_iframe()

# # Salvar o relatório como HTML
# profile.to_file("relatorio_merged_df.html")

# %%
df_merged['id'].value_counts() ## 166, 120, 73, 167, 163
# Out:
# id
# 93         33
# 102        33
# 112        33
# 117        33
# 96         33
#            ..
# 1283717     1
# 1283732     1
# 1283727     1
# 1283729     1
# 1283719     1
# Name: count, Length: 201, dtype: int64

# %%
case_1 = df_merged[df_merged['id'].isin([166, 120, 73, 167, 163])]

# %%
# Ver a quantidade de valores nulos por coluna
nulos_por_coluna = case_1.isna().sum()

# Ver a proporção de nulos por coluna
proporcao_nulos = case_1.isna().mean() * 100

# Mostrar a contagem e a proporção
print(nulos_por_coluna)
print(proporcao_nulos)
# Out:
# dados_fatura.taxa_energia_ativa_injetada_ponta_muc_mpt_te                       120
# supplier_cnpj                                                                     0
# dados_fatura.taxa_excedente_ufer_ponta                                           87
# dados_fatura.sistema_horossazonal                                                 0
# dados_fatura.medicao_distribuidora_consumo_ponta_te                               0
#                                                                                ...
# dados_fatura.valor_distribuidora_cofins                                           0
# dados_fatura.medicao_distribuidora_energia_ativa_injetada_ponta_ouc_opt_tusd    107
# supplier_type                                                                     0
# dados_fatura.medicao_distribuidora_excedente_ufer_ponta                          87
# company_group_type_rural                                                          0
# Length: 160, dtype: int64
# ...

# %%
# Remover as colunas que têm mais de 30% de valores nulos
limite_nulos = 0.30  # 30%

# Remover as colunas que têm mais que 30% de nulos
case_1_limpo = case_1.loc[:, case_1.isna().mean() < limite_nulos]

# Mostrar o DataFrame resultante
case_1_limpo.columns
# Out:
# Index(['supplier_cnpj', 'dados_fatura.sistema_horossazonal',
#        'dados_fatura.medicao_distribuidora_consumo_ponta_te',
#        'dados_fatura.cliente', 'dados_fatura.taxa_pis_pasep',
#        'company_subgroup', 'invoice_end_date', 'number_uc_consideration',
#        'is_trial', 'user_id', 'comercial_company_name', 'active',
#        'dados_fatura.id_fatura', 'supplier_uc_login',
#        'dados_fatura.taxa_consumo_fora_ponta_te',
#        'dados_fatura.valor_distribuidora_icms', 'potencia_geradora',
#        'af_invoice_history_months', 'dados_fatura.updated_at',
#        'dados_fatura.valor_distribuidora_cip', 'dados_fatura.taxa_cofins',
#        'dados_fatura.taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd',
#        'dados_fatura.taxa_energia_ativa_injetada_ponta_ouc_mpt_tusd',
#        'dados_fatura.datetime_update', 'tipo_de_fatura', 'invoice_start_date',
#        'dados_fatura.medicao_distribuidora_demanda_fora_ponta_indutivo',
# ...

# %%
case_1_limpo.dtypes.tolist()
# Out:
# [dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('bool'),
#  dtype('O'),
#  dtype('O'),
#  dtype('bool'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('bool'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
# ...

# %%
# Importando bibliotecas necessárias
import pandas as pd

# Identificar colunas do tipo datetime
datetime_cols = case_1_limpo.select_dtypes(include=['datetime']).columns

# Agrupar por 'id' e agregar as colunas datetime
result = case_1_limpo.groupby('id').agg({col: 'min' for col in datetime_cols})

# Exibir o resultado
result
# Out:
#     dados_fatura.data_emissao
# id
# 73                 2022-01-20
# 120                2021-12-08
# 163                2021-12-22
# 166                2021-12-13
# 167                2021-12-15

# %%
df_merged.columns.tolist() # 'company_group', 'id', 'invoice_end_day','comercial_subsidiary_name',
                        ## 'dados_fatura.taxa_energia_ativa_injetada_ponta_muc_mpt_tusd', 'dados_fatura.sistema_horossazonal',
# 'dados_fatura.medicao_distribuidora_energia_ativa_ponta_saldo',
# 'dados_fatura.valor_distribuidora_cip',
# 'dados_fatura.medicao_distribuidora_energia_ativa_injetada_ponta_muc_mpt_tusd',
# 'supplier_email',
# 'dados_fatura.aws_file_name',
# 'city_id',
# 'dados_fatura.medicao_distribuidora_demanda_fora_ponta_indutivo',
# 'dados_fatura.medicao_distribuidora_energia_ativa_injetada_ponta_ouc_mpt_tusd',
# 'company_subgroup',
# 'dados_fatura.medicao_distribuidora_energia_ativa_injetada_ponta_muc_mpt_te',
# 'dados_fatura.taxa_energia_ativa_injetada_ponta_ouc_opt_tusd','dados_fatura.med_dist_energia_ativa_injetada_fora_ponta_muc_mpt_te',
# 'dados_fatura.medicao_distribuidora_consumo_fora_ponta_tusd',
# 'company_group_type_rural',
# Out:
# ['dados_fatura.taxa_energia_ativa_injetada_ponta_muc_mpt_te',
#  'supplier_cnpj',
#  'dados_fatura.taxa_excedente_ufer_ponta',
#  'dados_fatura.sistema_horossazonal',
#  'dados_fatura.medicao_distribuidora_consumo_ponta_te',
#  'contact_address',
#  'dados_fatura.taxa_energia_ativa_injetada_ponta_muc_opt_tusd',
#  'dados_fatura.cliente',
#  'dados_fatura.taxa_pis_pasep',
#  'company_subgroup',
#  'invoice_end_date',
#  'dados_fatura.med_dist_energia_ativa_injetada_fora_ponta_muc_mpt_tusd',
#  'number_uc_consideration',
#  'is_trial',
#  'user_id',
#  'comercial_company_name',
#  'uuid_external_id',
#  'active',
#  'dados_fatura.id_fatura',
#  'supplier_uc_login',
#  'municipal_inscription',
#  'dados_fatura.taxa_consumo_fora_ponta_te',
#  'dados_fatura.valor_distribuidora_icms',
#  'contact_name',
#  'datetime_read',
#  'potencia_geradora',
#  'af_invoice_history_months',
#  'dados_fatura.updated_at',
#  'dados_fatura.valor_distribuidora_cip',
#  'dados_fatura.taxa_cofins',
# ...

# %%
case_1_limpo
# Out:
#        supplier_cnpj dados_fatura-sistema_horossazonal  \
# 53    63473235000110                             verde
# 82    63473235000110                             verde
# 85    07240641000162                             verde
# 89    07240641000162                             verde
# 92    07240641000162                             verde
# ...              ...                               ...
# 2099  63473235000110                             verde
# 2102  63473235000110                             verde
# 2110  63473235000110                             verde
# 2113  63473235000110                             VERDE
# 2115  63473235000110                             VERDE
#
#       dados_fatura-medicao_distribuidora_consumo_ponta_te  \
# 53                                             5597.000
# 82                                             5437.000
# 85                                             1473.950
# 89                                             1966.975
# ...

# %%
# case_1_limpo.to_csv('../Allianz/caso_1.csv')
# case_1_limpo.to_parquet('../zaninth/energy_demand_prediction/case_1_limpo.parquet', engine='pyarrow') 
caso_1 = pd.read_parquet('/Users/zaninth/energy_demand_prediction/case_1_limpo.parquet', engine='pyarrow')
caso_1
# Out:
#        supplier_cnpj dados_fatura-sistema_horossazonal  \
# 53    63473235000110                             verde
# 82    63473235000110                             verde
# 85    07240641000162                             verde
# 89    07240641000162                             verde
# 92    07240641000162                             verde
# ...              ...                               ...
# 2099  63473235000110                             verde
# 2102  63473235000110                             verde
# 2110  63473235000110                             verde
# 2113  63473235000110                             VERDE
# 2115  63473235000110                             VERDE
#
#       dados_fatura-medicao_distribuidora_consumo_ponta_te  \
# 53                                             5597.000
# 82                                             5437.000
# 85                                             1473.950
# 89                                             1966.975
# ...

# %%
case_1_limpo.columns = case_1_limpo.columns.str.replace('.', '_')
case_1_limpo.columns = case_1_limpo.columns.str.replace('-', '_')

# %%
caso_1['company_subgroup'].value_counts()
# Out:
# company_subgroup
# 13    99
# 7     33
# 8     33
# Name: count, dtype: int64

# %%
caso_1.columns.tolist()
# Out:
# ['supplier_cnpj',
#  'dados_fatura-sistema_horossazonal',
#  'dados_fatura-medicao_distribuidora_consumo_ponta_te',
#  'dados_fatura-cliente',
#  'dados_fatura-taxa_pis_pasep',
#  'company_subgroup',
#  'invoice_end_date',
#  'number_uc_consideration',
#  'is_trial',
#  'user_id',
#  'comercial_company_name',
#  'active',
#  'dados_fatura-id_fatura',
#  'supplier_uc_login',
#  'dados_fatura-taxa_consumo_fora_ponta_te',
#  'dados_fatura-valor_distribuidora_icms',
#  'potencia_geradora',
#  'af_invoice_history_months',
#  'dados_fatura-updated_at',
#  'dados_fatura-valor_distribuidora_cip',
#  'dados_fatura-taxa_cofins',
#  'dados_fatura-taxa_energia_ativa_injetada_fora_ponta_ouc_mpt_tusd',
#  'dados_fatura-taxa_energia_ativa_injetada_ponta_ouc_mpt_tusd',
#  'dados_fatura-datetime_update',
#  'tipo_de_fatura',
#  'invoice_start_date',
#  'dados_fatura-medicao_distribuidora_demanda_fora_ponta_indutivo',
#  'city_name',
#  'af_id',
#  'af_sync',
# ...

# %%
# Filtrando as colunas que começam com 'dados_fatura-'
dados_fatura_columns = [col for col in caso_1.columns if col.startswith('dados_fatura-')]
df_dados_fatura = caso_1[dados_fatura_columns]

# Exibindo o novo DataFrame
df_dados_fatura.head()
# Out:
#    dados_fatura-sistema_horossazonal  \
# 53                             verde
# 82                             verde
# 85                             verde
# 89                             verde
# 92                             verde
#
#     dados_fatura-medicao_distribuidora_consumo_ponta_te dados_fatura-cliente  \
# 53                                           5597.000         Freitas Varejo
# 82                                           5437.000         Freitas Varejo
# 85                                           1473.950       Sobral e Palacio
# 89                                           1966.975       Sobral e Palacio
# 92                                           1059.850       Sobral e Palacio
#
#     dados_fatura-taxa_pis_pasep  dados_fatura-id_fatura  \
# 53                         1.00                      -1
# 82                         0.99                      -1
# 85                         0.99                      -1
# ...
